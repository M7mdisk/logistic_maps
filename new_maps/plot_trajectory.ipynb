# %%
from different_maps import logistic_map,gauss_map,sine_map, run_map
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
x_0 = np.random.rand()
r = random.uniform(0,4)
r ,x_0 =2.804572315275718, 0.7477900820345867
iters = 25
# y = logistic_map(x_0,r,iters,0,0)
y = run_map(x_0,r,25,logistic_map.func)
plt.plot(list(range(iters)),y)
plt.ylim(ymin=0,ymax=1)
plt.xlabel("k",fontsize=20)
plt.ylabel(r"$x_k$",fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.tight_layout()
# plt.savefig("results/logistic_map_trajectory/Fig3_no_kick.jpg")
