# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

# %%
# df = pd.read_csv("results/slopes.csv")
start_iter=1000
df = pd.read_csv("slopesssss_1000.csv")
df
df = df[df["slope"] < 0 ]
df
# Out:
#      Unnamed: 0  start_iteration  epsilon  e_frequency    r     slope
# 0           0.0             1000      0.1          0.2 -1.0 -0.137082
# 4           4.0             1000      0.1          0.2  2.0 -0.072772
# 5           5.0             1000      0.1          0.2  2.5 -0.371950
# 6           6.0             1000      0.1          0.2  3.0 -0.257360
# 7           7.0             1000      0.1          0.2  3.5 -0.002613
# ..          ...              ...      ...          ...  ...       ...
# 345       345.0             1000      1.0          0.7  1.5 -0.003073
# 346       346.0             1000      1.0          0.7  2.0 -0.004371
# 360         NaN             1000      0.0          0.0 -1.0 -0.073334
# 364         NaN             1000      0.0          0.0  2.0 -0.002994
# 367         NaN             1000      0.0          0.0  3.5 -0.007070
#
# [225 rows x 6 columns]

# %%
df["slop_norm"] = abs(df["slope"])
df
# Out:
#      Unnamed: 0  start_iteration  epsilon  e_frequency    r     slope  \
# 0           0.0             1000      0.1          0.2 -1.0 -0.137082
# 4           4.0             1000      0.1          0.2  2.0 -0.072772
# 5           5.0             1000      0.1          0.2  2.5 -0.371950
# 6           6.0             1000      0.1          0.2  3.0 -0.257360
# 7           7.0             1000      0.1          0.2  3.5 -0.002613
# ..          ...              ...      ...          ...  ...       ...
# 345       345.0             1000      1.0          0.7  1.5 -0.003073
# 346       346.0             1000      1.0          0.7  2.0 -0.004371
# 360         NaN             1000      0.0          0.0 -1.0 -0.073334
# 364         NaN             1000      0.0          0.0  2.0 -0.002994
# 367         NaN             1000      0.0          0.0  3.5 -0.007070
#
#      slop_norm
# 0     0.137082
# 4     0.072772
# 5     0.371950
# 6     0.257360
# 7     0.002613
# ..         ...
# ...

# %%
min_value = abs(df['slope']).min()
max_value = abs(df['slope']).max()

# Perform Min-Max scaling
df['scaled_s'] = (abs(df['slope']) - min_value) / (max_value - min_value)

# %%
plt.clf()
plt.scatter(df["r"],df["epsilon"],s=df["scaled_s"]*500,c=df["e_frequency"],alpha=0.5)
plt.xlabel(r'$\mu$',fontsize=15)
c_bar = plt.colorbar()
c_bar.set_label(r'$q$',fontsize=15)
plt.ylabel(r'$\epsilon$',fontsize=15)
plt.savefig(f"start_{start_iter}.png")
